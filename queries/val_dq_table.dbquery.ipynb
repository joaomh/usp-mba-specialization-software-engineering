-- %%
SELECT * FROM 
workspace.default.qualidade_dados where regra like '%Volume%'

SELECT * FROM 
workspace.default.qualidade_dados where regra like '%Completude%'

SELECT * FROM 
workspace.default.qualidade_dados where regra like '%Unicidade%'

SELECT * FROM 
workspace.default.qualidade_dados where regra like '%Tipo%'

SELECT * FROM 
workspace.default.qualidade_dados where regra like '%Custom%'
