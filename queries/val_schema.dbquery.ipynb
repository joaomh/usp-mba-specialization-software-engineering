-- %%
-- =================================================================
-- 1. VALIDAÇÃO DE DIMENSÕES 
-- =================================================================

SELECT * FROM workspace.default.dim_cnae;
SELECT * FROM workspace.default.dim_motivo_situacao_cadastral;
SELECT * FROM workspace.default.dim_municipio;
SELECT * FROM workspace.default.dim_natureza_juridica;
SELECT * FROM workspace.default.dim_pais;
SELECT * FROM workspace.default.dim_qualificacao_socio;

-- =================================================================
-- 2. VALIDAÇÃO DE FATOS
-- =================================================================

SELECT * FROM workspace.default.fato_arrecadacao_ir_ipi       LIMIT 1000;
SELECT * FROM workspace.default.fato_arrecadacao_uf           LIMIT 1000;
SELECT * FROM workspace.default.fato_empresas                 LIMIT 1000;
SELECT * FROM workspace.default.fato_estabelecimentos         LIMIT 1000;
SELECT * FROM workspace.default.fato_socios                   LIMIT 1000;
SELECT * FROM workspace.default.fato_leitos_hospitalares      LIMIT 1000;

-- =================================================================
-- 3. TABELAS DATABRICKS
-- =================================================================
SELECT * FROM samples.accuweather.forecast_daily_calendar_imperial
